# %%
#Moment04:a
# Här låter jag användaren mata in fyrhörningens sidor, sedan kontrollerar om det är en rektangel eller kvadrat.
# Därefter beräknar programmet rektangelns area.

s1 = int(input("Ange rektangelns ena sida:"))
s2 = int(input("Ange rektangelns andra sida:"))
area = s1*s2

if s1==s2:
    print(" ")
    print(f"Felaktigt input. Ena sidan är {s1} och andra är {s2}. Detta är en kvadrat eftersom bägge sidorna är lika långa. Skriv gärna olika värden.")
else:
    print(" ")
    print(f"Rektangeln har sidorna {s1} och {s2} vilket gör att arean är {area}")
print(" ")
print("Höjden | Volymen")
print("_________________")
for i in range(1,11):
    print(i, "|",i*area)
print("_________________")

# %%
#Moment04:b
#Här utvecklas programmet så att informationen om sidorna lagras i en lista
total = []

while True:
    s1 = int(input("Ange den första sidan: "))
    s2 = int(input("Ange den andra sidan: "))
    area = s1*s2
    info = [s1, s2, area]
    print(f"Rektangelns sidor är {s1} och {s2}, vilket betyder att area är {area}")

    if s1 == s2:
        print("Båda sidorna är lika vilket innebär att det är en kvadrat. Använd gärna olika mått.")
        info.append("kvadrat")

    total.append(info)

    print("\nHöjd | Volym")
    print("-------------------")
    for i in range(1,11):
        print(f"{i} | {i*area}")

    fortsätt = input("Vill du göra en ny uträkning? (Y/N)? ")

    if fortsätt == "N" or fortsätt == "n":
        for t in total:
            if len(t)==4:
                print("Detta är en kvadrat! Sidorna är ", t[0], " och ", t[1], "Ange gärna olika värden.")
                print("-------------------")
            else:
                print("-------------------")
                print("Kvadraten har sidorna ", t[0], " och ", t[1],", arean är då: ", t[2])
        break
# Out:
# Rektangelns sidor är 3 och 6, vilket betyder att area är 18
#
# Höjd | Volym
# -------------------
# 1 | 18
# 2 | 36
# 3 | 54
# 4 | 72
# 5 | 90
# 6 | 108
# 7 | 126
# 8 | 144
# 9 | 162
# 10 | 180
# Rektangelns sidor är 3 och 7, vilket betyder att area är 21
#
# Höjd | Volym
# -------------------
# 1 | 21
# 2 | 42
# 3 | 63
# 4 | 84
# 5 | 105
# 6 | 126
# 7 | 147
# 8 | 168
# 9 | 189
# 10 | 210
# -------------------
# Kvadraten har sidorna  3  och  6 , arean är då:  18
# -------------------
# Kvadraten har sidorna  3  och  7 , arean är då:  21

# %%
#Moment04:c
#Programmet utvecklas yttligare och låter användaren mata in egen höjd
allt = []

while True:
    sida1 = int(input('Ange den första sidan: '))
    sida2 = int(input('Ange den andra sidan: '))
    area = sida1*sida2
    info = [sida1, sida2, area]
    volym = ''
    print('The retangle has sides '+str(sida1)+' and '+str(sida2) +
          ', which means that the area is '+str(area))
    while type(volym) != int:
        try:
            volym = int(
                input('Ange höjden för rätblocket: '))
            if volume <= 0:
                volume = 1
        except Exception as e:
            print(' ')

    if sida1 == sida2:
        print('Eftersom de båda sidorna är lika långa är detta en kvadrat.')
        info.append('kvadrat')

    allt.append(info)

    print('\nHöjd | Volym')
    print('-------------------')
    for i in range(1,11):
        print('\t'+str(i)+' | '+str(i*area))

    fortsatt = input('Vill du fortsätta programmet? (Y/N)? ')

    if fortsatt == 'N' or fortsatt == 'n':
        for data in allt:
            if len(data)==4:
                print('Fyrhörningens sidor är ', data[0], ' och ', data[1],
                    ' vilket får arean att bli ', data[2], ', som blir en kvadrat.')
            else:
                print('Fyrhörningens sidor är ', data[0], ' och ', data[1],
                    ', vilket får arean att bli ', data[2])
        break

# %%
# Uppgift 04 D
# Koden är relativt simpel så känner inte att jag behöver förklara den så nogrant.

allt = []
print('Detta verktyget används för att räkna ut arean av en rektangel respektive en kvadrat beroende på mått')

while True:
    sida1 = int(input('Ange den första sidan: '))
    sida2 = int(input('Ange den andra sidan: '))
    area = sida1*sida2
    info = [sida1, sida2, area]
    volym = ''
    print('The retangle has sides '+str(sida1)+' and '+str(sida2) +
          ', which means that the area is '+str(area))
    while type(volym) != int:
        try:
            volym = int(
                input('Ange höjden för rätblocket: '))
            if volume <= 0:
                volume = 1
        except Exception as e:
            print('Du har anget ett felaktigt tal!')

    if sida1 == sida2:
        print('Eftersom de båda sidorna är lika långa är detta en kvadrat.')
        info.append('kvadrat')

    allt.append(info)

    tal = []
    print('\nHöjd | Volym')
    print('-------------------')
    for i in range(1, volume+1):
        tal.append(str(i)+', '+str(i*area))
        print('\t', i, ' | '+str(i*area))
    info.insert(3, tal)
    fortsatt = input('Vill du fortsätta programmet? (Y/N)? ')

    if fortsatt == 'N' or fortsatt == 'n':
        for data in allt:
            if len(data)==4:
                print('Fyrhörningens sidor är ', data[0], ' och ', data[1],
                    ' vilket får arean att bli ', data[2], ', som blir en kvadrat.')
            else:
                print('Fyrhörningens sidor är ', data[0], ' och ', data[1],
                    ', vilket får arean att bli ', data[2])
        break

# %%
#UPPGIFT 04 E
# Först har jag delat upp uppgiften till olika funktioner, sedan använt dessa funktioner i mina beräkningar. 
# Koden är relativt simpel så känner inte att jag behöver förklara den så nogrant. 
def omkrets(sida1, sida2):
    print("Omkretsen av en rektangel med sidorna {} och {} är {}"
           .format(sida1, sida2, 2*(sida1+sida2)))

def fyrkantvol(area, volym):
    tal = []
    print('\nHöjd | Volym')
    print('-------------------')
    for i in range(1, volym+1):
        tal.append(str(i)+', '+str(i*area))
        print('\t', i, ' | '+str(i*area))
    return tal


def datan(allInfo):
    for data in allInfo:
        if len(data) > 4:
            print('Fyrhörningens sidor är ', data[0], ' och ', data[1],
                  ' vilket får arean att bli ', data[2], 'beräkningarna av höjden är ', data[3], ', fyrkanten är en kvadrat.')
        else:
            print('The rectangle has sides ', data[0], ' and ', data[1],
                  ', which makes the area ', data[2], 'calculation of the straight heights are ', data[3])

allt = []
print('Detta verktyget används för att räkna ut arean av en rektangel respektive en kvadrat beroende på mått')
print(' ')
while True:
    sida1 = int(input('Ange den första sidan: '))
    sida2 = int(input('Ange den andra sidan: '))
    area = sida1*sida2
    info = [sida1, sida2, area]
    volym = ''
    print('Rektangeln har sidorna '+str(sida1)+' och '+str(sida2) +
          ', som får area att bli '+str(area))
    while type(volym) != int:
        try:
            volym = int(
                input('Ange djup för rätblocket: '))
            if volume <= 0:
                volume = 1
        except Exception as e:
            print('')
    print(omkrets)
    if sida1 == sida2:
        print('Eftersom de båda sidorna är lika långa är detta en kvadrat.')
        info.append('kvadrat')
    runt = omkrets(sida1, sida2) 
    tal = fyrkantvol(sida1*sida2, volym)
    info.insert(3, tal)
    allt.append(info)   
   
    fortsatt = input('Vill du fortsätta programmet? (Y/N)? ')

    if fortsatt == 'N' or fortsatt == 'n':
        datan(allt)
        break
